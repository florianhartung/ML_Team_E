# %%
import pandas as pd
import matplotlib.pyplot as plt

import sys
import importlib

sys.path.append("../../magic-ml-images")
from magicdl import magic

sys.path.append("..")
from common import HexaToParallelogram
importlib.reload(HexaToParallelogram)
# Out:
# <module 'common.HexaToParallelogram' from 'c:\\Users\\bkars\\OneDrive\\Desktop\\Files\\Studium\\ML\\ML_Team_E\\src\\common\\..\\common\\HexaToParallelogram.py'>

# %%
protons = pd.read_parquet("c:/users/bkars/downloads/magic-protons.parquet")

# %%
p = protons["clean_image_m1"].iloc[0]

h = HexaToParallelogram.HexaToParallelogram(-20)
result = h.forward(p)

plt.imshow(result.numpy(), cmap='hot', interpolation='nearest')
plt.colorbar()
plt.show()
